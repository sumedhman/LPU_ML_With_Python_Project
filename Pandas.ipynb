# %% [markdown]
# #### **PANDAS: INTRODUCTION**
# > It is often said that 80% of data analysis is spent on the data cleaning and preparing data. To get a handle on the problem, this section focuses on a small, but important aspect of data manipulation and cleaning with Pandas.
# #### Data Structures
# **There are two data structures are there in Pandas -**<br>
# * **Series -** It is one-dimensional labeled array capable of holding any data type (integer, strings, floating point numbers, Python objects etc.) of data. The axis is collectively referred to as index.
#
# * **Data Frame -** It is a two-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL Table or a Series of objects.
#
# #### Series Data Structure:
# **pandas.core.series.Series(data, index, dtype, copy)**<br>
# * **data -** data takes various forms like ndarray, list, constants, dictionary etc.<br>
# * **index -** it is unique and hashable for easy identification.<br>
# * **dtype -** it is for data type.<br>
# * **copy -** copy data, and its default value is False. It only affects for Series or one dimensional ndarray inputs.

# %%
# importing required modules
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# creating empty Series
s = pd.Series()
print (s, type(s), id(s))
# Out:
# Series([], dtype: float64) <class 'pandas.core.series.Series'> 1937091658704

# %%
# create a Series from a ndarray
arr_data = np.array(['apple', 'banana', 'cherry', 'pineapple'])
print (arr_data, len(arr_data), type(arr_data), id(arr_data))
s = pd.Series(data = arr_data)
print (s)
print (type(s))
print (len(s))
print (id(s))
print (s[2], s[3])
print (s[:3])
print (s[1:])
# Out:
# ['apple' 'banana' 'cherry' 'pineapple'] 4 <class 'numpy.ndarray'> 1937093718928
# 0        apple
# 1       banana
# 2       cherry
# 3    pineapple
# dtype: object
# <class 'pandas.core.series.Series'>
# 4
# 1937091658560
# cherry pineapple
# 0     apple
# 1    banana
# 2    cherry
# dtype: object
# 1       banana
# 2       cherry
# 3    pineapple
# dtype: object

# %%
arr_data = np.array([100, 200, 400, 500, 300])
s = pd.Series(data = arr_data, copy = False)
print (s)
print (s[0], s[2])
s[0] = 999; arr_data[2] = 777
print (s)
print (arr_data)
# Out:
# 0    100
# 1    200
# 2    400
# 3    500
# 4    300
# dtype: int32
# 100 400
# 0    999
# 1    200
# 2    777
# 3    500
# 4    300
# dtype: int32
# [999 200 777 500 300]

# %%
arr_data = np.array([100, 200, 400, 500, 300])
s = pd.Series(data = arr_data, copy = True)
print (s)
print (s[0], s[2])
s[0] = 999; arr_data[2] = 777
print (s)
print (arr_data)
# Out:
# 0    100
# 1    200
# 2    400
# 3    500
# 4    300
# dtype: int32
# 100 400
# 0    999
# 1    200
# 2    400
# 3    500
# 4    300
# dtype: int32
# [100 200 777 500 300]

# %%
arr_data = np.array(['apple', 'banana', 'cherry', 'pineapple'])
print (arr_data, len(arr_data), type(arr_data), id(arr_data))

s = pd.Series(data = arr_data, index = [100, 101, 102, 103])
print (s)
print (s[101], s[103])
# Out:
# ['apple' 'banana' 'cherry' 'pineapple'] 4 <class 'numpy.ndarray'> 1937062671056
# 100        apple
# 101       banana
# 102       cherry
# 103    pineapple
# dtype: object
# banana pineapple

# %%
s = pd.Series(data = arr_data, index = [100, 101, 100, 103])
print (s)
print (s[101], s[103])
print (s[100])
# Out:
# 100        apple
# 101       banana
# 100       cherry
# 103    pineapple
# dtype: object
# banana pineapple
# 100     apple
# 100    cherry
# dtype: object

# %%
arr_data = np.array(['apple', 'banana', 'cherry', 'pineapple'])
print (arr_data, len(arr_data), type(arr_data), id(arr_data))

s = pd.Series(data = arr_data, index = ['fruit-1', 'fruit-2', 'fruit-3', 'fruit-4'])
print (s)
print (s['fruit-1'], s['fruit-3'], s[0], s[2])
# Out:
# ['apple' 'banana' 'cherry' 'pineapple'] 4 <class 'numpy.ndarray'> 1937062673744
# fruit-1        apple
# fruit-2       banana
# fruit-3       cherry
# fruit-4    pineapple
# dtype: object
# apple cherry apple cherry

# %%
# create a Series from a dictionary data
dict_data = {'apple':100, 'banana':202, 'coconut':450, 'mango':435}
s = pd.Series(data = dict_data)
print (s)
print (s['coconut'], s[2], s['mango'], s[3])
# Out:
# apple      100
# banana     202
# coconut    450
# mango      435
# dtype: int64
# 450 450 435 435

# %%
s = pd.Series(data = dict_data, index = ['apple', 'coconut', 'mango', 'banana', 'mango', 'banana', 'lime', 'lemon'])
print (s)
print (s['coconut'], s[1])
print (s['mango'])
print (s[3])
print (s['lime'])
# Out:
# apple      100.0
# coconut    450.0
# mango      435.0
# banana     202.0
# mango      435.0
# banana     202.0
# lime         NaN
# lemon        NaN
# dtype: float64
# 450.0 450.0
# mango    435.0
# mango    435.0
# dtype: float64
# 202.0
# nan

# %%
# create a Series from a scalar data
s = pd.Series(5, index = [0, 2, 1, 4, 3, 5])
print (s)
s = pd.Series(5, index = [0, 2, 1, 4, 3, 5, 2, 1, 4])
print (s)
print (s[2])
# Out:
# 0    5
# 2    5
# 1    5
# 4    5
# 3    5
# 5    5
# dtype: int64
# 0    5
# 2    5
# 1    5
# 4    5
# 3    5
# 5    5
# 2    5
# 1    5
# 4    5
# dtype: int64
# 2    5
# 2    5
# dtype: int64

# %%
# Create a Series from a list
s = pd.Series(data = [101, 202, 303, 404, 505, 606], index = ['red', 'green', 'blue', 'purple', 'magenta', 'white'])
print (s)
print (s['red'])
print (s[::-1])
print (s[2:5])
# Out:
# red        101
# green      202
# blue       303
# purple     404
# magenta    505
# white      606
# dtype: int64
# 101
# white      606
# magenta    505
# purple     404
# blue       303
# green      202
# red        101
# dtype: int64
# blue       303
# purple     404
# magenta    505
# dtype: int64

# %%
print (s)
print (s[[0, 3, 2, 1]])
print (s[['green', 'white', 'purple', 'magenta']])
# Out:
# red        101
# green      202
# blue       303
# purple     404
# magenta    505
# white      606
# dtype: int64
# red       101
# purple    404
# blue      303
# green     202
# dtype: int64
# green      202
# white      606
# purple     404
# magenta    505
# dtype: int64

# %%
s = pd.Series(data = [101, 902, 203, 604, 205, 606], index = ['red', 'green', 'blue', 'purple', 'magenta', 'white'])
print (s)
print (s.count(), len(s))
print (s.sort_index())
print (s.sort_values())
# Out:
# red        101
# green      902
# blue       203
# purple     604
# magenta    205
# white      606
# dtype: int64
# 6 6
# blue       203
# green      902
# magenta    205
# purple     604
# red        101
# white      606
# dtype: int64
# red        101
# blue       203
# magenta    205
# purple     604
# white      606
# green      902
# dtype: int64

# %%
print (s)
print (s.argmax(), s.argmin(), max(s), min(s), len(s), sum(s), sum(s) / len(s))
# Out:
# red        101
# green      902
# blue       203
# purple     604
# magenta    205
# white      606
# dtype: int64
# 1 0 902 101 6 2621 436.8333333333333

# %% [markdown]
# #### Data Frame Data Structure:

# %%
data_dict = {'emp_name':['Amal', 'Kamal', 'Bimal', 'Shyamal', 'Sundar'], 'emp_age':[34, 54, 44, 33, 24]}
emp_id = [101, 102, 103, 104, 105]
print (data_dict, type(data_dict))
print (emp_id, type(emp_id))
# Out:
# {'emp_name': ['Amal', 'Kamal', 'Bimal', 'Shyamal', 'Sundar'], 'emp_age': [34, 54, 44, 33, 24]} <class 'dict'>
# [101, 102, 103, 104, 105] <class 'list'>

# %%
df = pd.DataFrame(data = data_dict)
df
# Out:
#   emp_name  emp_age
# 0     Amal       34
# 1    Kamal       54
# 2    Bimal       44
# 3  Shyamal       33
# 4   Sundar       24

# %%
df = pd.DataFrame(data = data_dict, index = emp_id)
df
# Out:
#     emp_name  emp_age
# 101     Amal       34
# 102    Kamal       54
# 103    Bimal       44
# 104  Shyamal       33
# 105   Sundar       24

# %%
df = df.reset_index()
print (df)
df
# Out:
#    index emp_name  emp_age
# 0    101     Amal       34
# 1    102    Kamal       54
# 2    103    Bimal       44
# 3    104  Shyamal       33
# 4    105   Sundar       24
#    index emp_name  emp_age
# 0    101     Amal       34
# 1    102    Kamal       54
# 2    103    Bimal       44
# 3    104  Shyamal       33
# 4    105   Sundar       24

# %% [markdown]
# #### Create DataFrame

# %%
# creating DataFrame user1
user_data = [['alice', 19, 'F', 'student'], ['john', 26, 'M', 'student']]    # list of lists
user_columns = ['name', 'age', 'gender', 'job']
user1 = pd.DataFrame(data = user_data, columns = user_columns)
user1
# Out:
#     name  age gender      job
# 0  alice   19      F  student
# 1   john   26      M  student

# %%
# creating DataFrame user2
user_data = dict(name = ['eric', 'paul'], age = [22, 58], gender = ['M', 'F'], job = ['student', 'manager'])    # dictionary
user2 = pd.DataFrame(data = user_data)
user2
# Out:
#    name  age gender      job
# 0  eric   22      M  student
# 1  paul   58      F  manager

# %%
# creating DataFrame user3
user_data = {'name':['peter', 'julie'], 'age':[33, 44], 'gender':['M', 'F'], 'job':['engineer', 'scientist']}    # dictionary
user3 = pd.DataFrame(data = user_data)
user3
# Out:
#     name  age gender        job
# 0  peter   33      M   engineer
# 1  julie   44      F  scientist

# %% [markdown]
# #### Concatenate DataFrame

# %%
users = user1.append(user2)
users
# Out:
#     name  age gender      job
# 0  alice   19      F  student
# 1   john   26      M  student
# 0   eric   22      M  student
# 1   paul   58      F  manager

# %%
users = user1.append(user2, ignore_index = True)
users
# Out:
#     name  age gender      job
# 0  alice   19      F  student
# 1   john   26      M  student
# 2   eric   22      M  student
# 3   paul   58      F  manager

# %%
users = user1.append(user2).append(user3, ignore_index = True)
users
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
users = pd.concat([user1, user2, user3])
users
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 0   eric   22      M    student
# 1   paul   58      F    manager
# 0  peter   33      M   engineer
# 1  julie   44      F  scientist

# %%
users = pd.concat([user1, user2, user3], ignore_index = True)
users
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %% [markdown]
# #### DataFrame to Numpy ndArray

# %%
user1
# Out:
#     name  age gender      job
# 0  alice   19      F  student
# 1   john   26      M  student

# %%
user1[['name', 'job']]
# Out:
#     name      job
# 0  alice  student
# 1   john  student

# %%
arr_data = user1[['name', 'job']].to_numpy()
print (arr_data, type(arr_data))
print ()
arr_data = user1.to_numpy()
print (arr_data, type(arr_data))
print ()
arr_data = np.array(user1)
print (arr_data, type(arr_data))
# Out:
# [['alice' 'student']
#  ['john' 'student']] <class 'numpy.ndarray'>
#
# [['alice' 19 'F' 'student']
#  ['john' 26 'M' 'student']] <class 'numpy.ndarray'>
#
# [['alice' 19 'F' 'student']
#  ['john' 26 'M' 'student']] <class 'numpy.ndarray'>

# %% [markdown]
# #### Join DataFrame

# %%
dict_data = dict(name = ['alice', 'john', 'eric', 'julie', 'anderson'], height = [165, 180, 175, 169, 180])
user4 = pd.DataFrame(data = dict_data)
user4
# Out:
#        name  height
# 0     alice     165
# 1      john     180
# 2      eric     175
# 3     julie     169
# 4  anderson     180

# %%
users
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
# inner join: All common rows from the both data frames
merge_inner = pd.merge(users, user4, on = "name", how = "inner")
merge_inner
# Out:
#     name  age gender        job  height
# 0  alice   19      F    student     165
# 1   john   26      M    student     180
# 2   eric   22      M    student     175
# 3  julie   44      F  scientist     169

# %%
# outer join: All rows from the both data frames
merge_outer = pd.merge(users, user4, on = "name", how = "outer")
merge_outer
# Out:
#        name   age gender        job  height
# 0     alice  19.0      F    student   165.0
# 1      john  26.0      M    student   180.0
# 2      eric  22.0      M    student   175.0
# 3      paul  58.0      F    manager     NaN
# 4     peter  33.0      M   engineer     NaN
# 5     julie  44.0      F  scientist   169.0
# 6  anderson   NaN    NaN        NaN   180.0

# %%
# left outer join: All rows from the left data frame and matching rows from the right data frame
merge_left = pd.merge(users, user4, on = "name", how = "left")
merge_left
# Out:
#     name  age gender        job  height
# 0  alice   19      F    student   165.0
# 1   john   26      M    student   180.0
# 2   eric   22      M    student   175.0
# 3   paul   58      F    manager     NaN
# 4  peter   33      M   engineer     NaN
# 5  julie   44      F  scientist   169.0

# %%
# right outer join: All matching rows from the left data frame and all rows from the right data frame
merge_right = pd.merge(users, user4, on = "name", how = "right")
merge_right
# Out:
#        name   age gender        job  height
# 0     alice  19.0      F    student     165
# 1      john  26.0      M    student     180
# 2      eric  22.0      M    student     175
# 3     julie  44.0      F  scientist     169
# 4  anderson   NaN    NaN        NaN     180

# %%
help(pd.merge)

# %% [markdown]
# #### Summarizing

# %%
users
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
print (type(users))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
users.head()
# Out:
#     name  age gender       job
# 0  alice   19      F   student
# 1   john   26      M   student
# 2   eric   22      M   student
# 3   paul   58      F   manager
# 4  peter   33      M  engineer

# %%
users.head(3)
# Out:
#     name  age gender      job
# 0  alice   19      F  student
# 1   john   26      M  student
# 2   eric   22      M  student

# %%
users.tail()
# Out:
#     name  age gender        job
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
users.tail(3)
# Out:
#     name  age gender        job
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
users.any()
# Out:
# name      True
# age       True
# gender    True
# job       True
# dtype: bool

# %%
users.sample()
# Out:
#     name  age gender        job
# 5  julie   44      F  scientist

# %%
users.sample(3)
# Out:
#     name  age gender        job
# 1   john   26      M    student
# 5  julie   44      F  scientist
# 2   eric   22      M    student

# %%
print (users.index)
print (users.columns)
print (users.dtypes)
print (type(users.dtypes))
# Out:
# RangeIndex(start=0, stop=6, step=1)
# Index(['name', 'age', 'gender', 'job'], dtype='object')
# name      object
# age        int64
# gender    object
# job       object
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
users
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
print (users.shape)
print (f"So the DataFrame is having {users.shape[0]} number of rows and {users.shape[1]} number of columns...")
print (users.values)
print (type(users.values), users.values.shape, users.values.ndim, users.values.size)
# Out:
# (6, 4)
# So the DataFrame is having 6 number of rows and 4 number of columns...
# [['alice' 19 'F' 'student']
#  ['john' 26 'M' 'student']
#  ['eric' 22 'M' 'student']
#  ['paul' 58 'F' 'manager']
#  ['peter' 33 'M' 'engineer']
#  ['julie' 44 'F' 'scientist']]
# <class 'numpy.ndarray'> (6, 4) 2 24

# %%
print (users.job)
print (users.job.value_counts())
print (users.gender)
print (users.gender.value_counts())
# Out:
# 0      student
# 1      student
# 2      student
# 3      manager
# 4     engineer
# 5    scientist
# Name: job, dtype: object
# student      3
# manager      1
# engineer     1
# scientist    1
# Name: job, dtype: int64
# 0    F
# 1    M
# 2    M
# 3    F
# 4    M
# 5    F
# Name: gender, dtype: object
# F    3
# M    3
# Name: gender, dtype: int64

# %%
users.describe()
# Out:
#              age
# count   6.000000
# mean   33.666667
# std    14.895189
# min    19.000000
# 25%    23.000000
# 50%    29.500000
# 75%    41.250000
# max    58.000000

# %%
users.describe(include='all')
# Out:
#          name        age gender      job
# count       6   6.000000      6        6
# unique      6        NaN      2        4
# top     alice        NaN      F  student
# freq        1        NaN      3        3
# mean      NaN  33.666667    NaN      NaN
# std       NaN  14.895189    NaN      NaN
# min       NaN  19.000000    NaN      NaN
# 25%       NaN  23.000000    NaN      NaN
# 50%       NaN  29.500000    NaN      NaN
# 75%       NaN  41.250000    NaN      NaN
# max       NaN  58.000000    NaN      NaN

# %%
users.describe(include=['object'])
# Out:
#          name gender      job
# count       6      6        6
# unique      6      2        4
# top     alice      F  student
# freq        1      3        3

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     6 non-null      int64
#  2   gender  6 non-null      object
#  3   job     6 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 320.0+ bytes

# %% [markdown]
# #### Column Selection

# %%
users
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
print (users.job)
print (users['job'])
# Out:
# 0      student
# 1      student
# 2      student
# 3      manager
# 4     engineer
# 5    scientist
# Name: job, dtype: object
# 0      student
# 1      student
# 2      student
# 3      manager
# 4     engineer
# 5    scientist
# Name: job, dtype: object

# %%
users[['job', 'age']]
# Out:
#          job  age
# 0    student   19
# 1    student   26
# 2    student   22
# 3    manager   58
# 4   engineer   33
# 5  scientist   44

# %%
my_cols = ['job', 'age']
users[my_cols]
# Out:
#          job  age
# 0    student   19
# 1    student   26
# 2    student   22
# 3    manager   58
# 4   engineer   33
# 5  scientist   44

# %% [markdown]
# #### Row Selection

# %%
df = users.copy()
df
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
print (df.iloc[3], type(df.iloc[3]))
print (df.loc[3], type(df.loc[3]))
# Out:
# name         paul
# age            58
# gender          F
# job       manager
# Name: 3, dtype: object <class 'pandas.core.series.Series'>
# name         paul
# age            58
# gender          F
# job       manager
# Name: 3, dtype: object <class 'pandas.core.series.Series'>

# %%
df
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
print (df.iloc[4][3], df.iloc[4]['job'], df.loc[4][3], df.loc[4]['job'])
print (df.iloc[4, 3], df.iloc[4]['job'], df.loc[4][3], df.loc[4, 'job'])
print (df.shape, len(df), df.ndim, df.size)
# Out:
# engineer engineer engineer engineer
# engineer engineer engineer engineer
# (6, 4) 6 2 24

# %%
print (merge_outer.size)
merge_outer
# Out:
# 35
#        name   age gender        job  height
# 0     alice  19.0      F    student   165.0
# 1      john  26.0      M    student   180.0
# 2      eric  22.0      M    student   175.0
# 3      paul  58.0      F    manager     NaN
# 4     peter  33.0      M   engineer     NaN
# 5     julie  44.0      F  scientist   169.0
# 6  anderson   NaN    NaN        NaN   180.0

# %%
df
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
# increasing all age values by 199
df = users.copy()
for i in range(df.shape[0]):
    current_row = df.iloc[i]
    # print (current_row)
    current_row.age += 100
    df.iloc[i] = current_row
df
# Out:
#     name  age gender        job
# 0  alice  119      F    student
# 1   john  126      M    student
# 2   eric  122      M    student
# 3   paul  158      F    manager
# 4  peter  133      M   engineer
# 5  julie  144      F  scientist

# %% [markdown]
# #### Row Selection and Filtering

# %%
print (users.age)
print (users.age < 40)
print (users[users.age < 40].job)
users[users.age < 40]
# Out:
# 0    19
# 1    26
# 2    22
# 3    58
# 4    33
# 5    44
# Name: age, dtype: int64
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# Name: age, dtype: bool
# 0     student
# 1     student
# 2     student
# 4    engineer
# Name: job, dtype: object
#     name  age gender       job
# 0  alice   19      F   student
# 1   john   26      M   student
# 2   eric   22      M   student
# 4  peter   33      M  engineer

# %%
# select name, age, job from users where age < 40;
users[users.age < 40][['name', 'age', 'job']]
# Out:
#     name  age       job
# 0  alice   19   student
# 1   john   26   student
# 2   eric   22   student
# 4  peter   33  engineer

# %%
print ((users.age > 30) & (users.gender == "F"))
users[(users.age > 30) & (users.gender == "F")]
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool
#     name  age gender        job
# 3   paul   58      F    manager
# 5  julie   44      F  scientist

# %%
users[(users.age > 30) & (users.gender == "F")][['name', 'age', 'job']]
# Out:
#     name  age        job
# 3   paul   58    manager
# 5  julie   44  scientist

# %%
users[(users.age > 30) | (users.gender == "F")]
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
users[(users.age > 30) | (users.gender == "F")][['name', 'age', 'job']]
# Out:
#     name  age        job
# 0  alice   19    student
# 3   paul   58    manager
# 4  peter   33   engineer
# 5  julie   44  scientist

# %%
users[(users.job == "engineer") | (users.job == 'student')][['name', 'job', 'gender', 'age']]
# Out:
#     name       job gender  age
# 0  alice   student      F   19
# 1   john   student      M   26
# 2   eric   student      M   22
# 4  peter  engineer      M   33

# %%
users[users.job.isin(["engineer", 'student'])][['name', 'job', 'gender', 'age']]
# Out:
#     name       job gender  age
# 0  alice   student      F   19
# 1   john   student      M   26
# 2   eric   student      M   22
# 4  peter  engineer      M   33

# %% [markdown]
# #### Sorting

# %%
df = users.copy()
print (df.age.sort_values())
df.sort_values(by = 'age')
# Out:
# 0    19
# 2    22
# 1    26
# 4    33
# 5    44
# 3    58
# Name: age, dtype: int64
#     name  age gender        job
# 0  alice   19      F    student
# 2   eric   22      M    student
# 1   john   26      M    student
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist
# 3   paul   58      F    manager

# %%
df.sort_values(by = 'age', ascending = False)
# Out:
#     name  age gender        job
# 3   paul   58      F    manager
# 5  julie   44      F  scientist
# 4  peter   33      M   engineer
# 1   john   26      M    student
# 2   eric   22      M    student
# 0  alice   19      F    student

# %%
df.sort_values(by = 'age', ascending = False, inplace = True)
df.index = range(0, df.shape[0])
df
# Out:
#     name  age gender        job
# 0   paul   58      F    manager
# 1  julie   44      F  scientist
# 2  peter   33      M   engineer
# 3   john   26      M    student
# 4   eric   22      M    student
# 5  alice   19      F    student

# %% [markdown]
# #### Unpivot and Pivot
# * **Unpivot ->** Wide Format (Unstacked Format) to Long Format (Stacked Format)<br>
# * **Pivot ->** Long Format (Stacked Format) to Wide Format (Unstacked Format)<br>

# %%
# performing Unpivot operation converting Wide Format (Unstacked Format) to Long Format (Stacked Format)
stacked = pd.melt(users, id_vars = "name", var_name = "variable", value_name = "value")
stacked
# Out:
#      name variable      value
# 0   alice      age         19
# 1    john      age         26
# 2    eric      age         22
# 3    paul      age         58
# 4   peter      age         33
# 5   julie      age         44
# 6   alice   gender          F
# 7    john   gender          M
# 8    eric   gender          M
# 9    paul   gender          F
# 10  peter   gender          M
# 11  julie   gender          F
# 12  alice      job    student
# 13   john      job    student
# 14   eric      job    student
# 15   paul      job    manager
# 16  peter      job   engineer
# 17  julie      job  scientist

# %%
# performing Pivot operation converting Long Format (Stacked Format) to Wide Format (Unstacked Format) 
unstacked = stacked.pivot(index = 'name', columns = 'variable', values = 'value')
unstacked
# Out:
# variable age gender        job
# name
# alice     19      F    student
# eric      22      M    student
# john      26      M    student
# julie     44      F  scientist
# paul      58      F    manager
# peter     33      M   engineer

# %%
unstacked.reset_index(inplace = True)

# %%
unstacked.columns.name = ""
unstacked
# Out:
#     name age gender        job
# 0  alice  19      F    student
# 1   eric  22      M    student
# 2   john  26      M    student
# 3  julie  44      F  scientist
# 4   paul  58      F    manager
# 5  peter  33      M   engineer

# %% [markdown]
# #### Quality Control: Duplicate Data

# %%
df = users.copy()
df
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
df.iloc[0]
# Out:
# name        alice
# age            19
# gender          F
# job       student
# Name: 0, dtype: object

# %%
df = df.append(df.iloc[0])
df = df.append(df.iloc[2])
df = df.append(df.iloc[4])
df = df.append(df.iloc[3], ignore_index=True)

# %%
df.sort_values(by = "name", inplace=True)
df.index = range(0, df.shape[0])
df
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1  alice   19      F    student
# 2   eric   22      M    student
# 3   eric   22      M    student
# 4   john   26      M    student
# 5  julie   44      F  scientist
# 6   paul   58      F    manager
# 7   paul   58      F    manager
# 8  peter   33      M   engineer
# 9  peter   33      M   engineer

# %%
print (df.duplicated())
print (sum(df.duplicated()))
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9     True
# dtype: bool
# 4

# %%
print (~df.duplicated())
print (sum(~df.duplicated()))
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# 9    False
# dtype: bool
# 6

# %%
df[df.duplicated()]
# Out:
#     name  age gender       job
# 1  alice   19      F   student
# 3   eric   22      M   student
# 7   paul   58      F   manager
# 9  peter   33      M  engineer

# %%
df[~df.duplicated()]
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 2   eric   22      M    student
# 4   john   26      M    student
# 5  julie   44      F  scientist
# 6   paul   58      F    manager
# 8  peter   33      M   engineer

# %%
print (df.job.duplicated())
print (sum(df['job'].duplicated()))
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6    False
# 7     True
# 8    False
# 9     True
# Name: job, dtype: bool
# 6

# %%
print (df[['job', 'gender']].duplicated())
print (sum(df[['job', 'gender']].duplicated()))
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7     True
# 8    False
# 9     True
# dtype: bool
# 5

# %%
df
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1  alice   19      F    student
# 2   eric   22      M    student
# 3   eric   22      M    student
# 4   john   26      M    student
# 5  julie   44      F  scientist
# 6   paul   58      F    manager
# 7   paul   58      F    manager
# 8  peter   33      M   engineer
# 9  peter   33      M   engineer

# %%
df.drop_duplicates(inplace=True)
df.index = range(0, df.shape[0])
df
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   eric   22      M    student
# 2   john   26      M    student
# 3  julie   44      F  scientist
# 4   paul   58      F    manager
# 5  peter   33      M   engineer

# %% [markdown]
# #### Quality Control: Missing Data

# %%
df = merge_left.copy()
df
# Out:
#     name  age gender        job  height
# 0  alice   19      F    student   165.0
# 1   john   26      M    student   180.0
# 2   eric   22      M    student   175.0
# 3   paul   58      F    manager     NaN
# 4  peter   33      M   engineer     NaN
# 5  julie   44      F  scientist   169.0

# %%
df.describe(include='all')
# Out:
#          name        age gender      job      height
# count       6   6.000000      6        6    4.000000
# unique      6        NaN      2        4         NaN
# top     alice        NaN      F  student         NaN
# freq        1        NaN      3        3         NaN
# mean      NaN  33.666667    NaN      NaN  172.250000
# std       NaN  14.895189    NaN      NaN    6.601767
# min       NaN  19.000000    NaN      NaN  165.000000
# 25%       NaN  23.000000    NaN      NaN  168.000000
# 50%       NaN  29.500000    NaN      NaN  172.000000
# 75%       NaN  41.250000    NaN      NaN  176.250000
# max       NaN  58.000000    NaN      NaN  180.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     6 non-null      int64
#  2   gender  6 non-null      object
#  3   job     6 non-null      object
#  4   height  4 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 288.0+ bytes

# %%
print (df.height)
print (df.height.isnull())
print (df.height.isnull().sum())
df[df.height.isnull()]
# Out:
# 0    165.0
# 1    180.0
# 2    175.0
# 3      NaN
# 4      NaN
# 5    169.0
# Name: height, dtype: float64
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# Name: height, dtype: bool
# 2
#     name  age gender       job  height
# 3   paul   58      F   manager     NaN
# 4  peter   33      M  engineer     NaN

# %%
df[~df.height.isnull()]
# Out:
#     name  age gender        job  height
# 0  alice   19      F    student   165.0
# 1   john   26      M    student   180.0
# 2   eric   22      M    student   175.0
# 5  julie   44      F  scientist   169.0

# %%
df.isnull()
# Out:
#     name    age  gender    job  height
# 0  False  False   False  False   False
# 1  False  False   False  False   False
# 2  False  False   False  False   False
# 3  False  False   False  False    True
# 4  False  False   False  False    True
# 5  False  False   False  False   False

# %%
~df.isnull()
# Out:
#    name   age  gender   job  height
# 0  True  True    True  True    True
# 1  True  True    True  True    True
# 2  True  True    True  True    True
# 3  True  True    True  True   False
# 4  True  True    True  True   False
# 5  True  True    True  True    True

# %%
df.notnull()
# Out:
#    name   age  gender   job  height
# 0  True  True    True  True    True
# 1  True  True    True  True    True
# 2  True  True    True  True    True
# 3  True  True    True  True   False
# 4  True  True    True  True   False
# 5  True  True    True  True    True

# %%
# Strategy - 1 (Deleting rows containing missing values)
df = merge_outer.copy()
df.dropna(inplace=True)
df
# Out:
#     name   age gender        job  height
# 0  alice  19.0      F    student   165.0
# 1   john  26.0      M    student   180.0
# 2   eric  22.0      M    student   175.0
# 5  julie  44.0      F  scientist   169.0

# %%
df = merge_outer.copy()
df.dropna(inplace = True, how = "all")
df
# Out:
#        name   age gender        job  height
# 0     alice  19.0      F    student   165.0
# 1      john  26.0      M    student   180.0
# 2      eric  22.0      M    student   175.0
# 3      paul  58.0      F    manager     NaN
# 4     peter  33.0      M   engineer     NaN
# 5     julie  44.0      F  scientist   169.0
# 6  anderson   NaN    NaN        NaN   180.0

# %%
# Strategy - 2 (filling up missing values)
df = merge_left.copy()
df.fillna(0, inplace = True)
df
# Out:
#     name  age gender        job  height
# 0  alice   19      F    student   165.0
# 1   john   26      M    student   180.0
# 2   eric   22      M    student   175.0
# 3   paul   58      F    manager     0.0
# 4  peter   33      M   engineer     0.0
# 5  julie   44      F  scientist   169.0

# %%
df = merge_left.copy()
mean_height = df.height.mean()
print (mean_height)
df.fillna(mean_height, inplace = True)
df
# Out:
# 172.25
#     name  age gender        job  height
# 0  alice   19      F    student  165.00
# 1   john   26      M    student  180.00
# 2   eric   22      M    student  175.00
# 3   paul   58      F    manager  172.25
# 4  peter   33      M   engineer  172.25
# 5  julie   44      F  scientist  169.00

# %%
df = merge_left.copy()
median_height = df.height.median()
print (median_height)
df.fillna(median_height, inplace = True)
df
# Out:
# 172.0
#     name  age gender        job  height
# 0  alice   19      F    student   165.0
# 1   john   26      M    student   180.0
# 2   eric   22      M    student   175.0
# 3   paul   58      F    manager   172.0
# 4  peter   33      M   engineer   172.0
# 5  julie   44      F  scientist   169.0

# %%
df = merge_outer.copy()
df.sort_values(by = 'age', inplace = True)
df.index = range(0, df.shape[0])
df
# Out:
#        name   age gender        job  height
# 0     alice  19.0      F    student   165.0
# 1      eric  22.0      M    student   175.0
# 2      john  26.0      M    student   180.0
# 3     peter  33.0      M   engineer     NaN
# 4     julie  44.0      F  scientist   169.0
# 5      paul  58.0      F    manager     NaN
# 6  anderson   NaN    NaN        NaN   180.0

# %%
df.fillna(method = 'pad', inplace = True)   # forward fill
df
# Out:
#        name   age gender        job  height
# 0     alice  19.0      F    student   165.0
# 1      eric  22.0      M    student   175.0
# 2      john  26.0      M    student   180.0
# 3     peter  33.0      M   engineer   180.0
# 4     julie  44.0      F  scientist   169.0
# 5      paul  58.0      F    manager   169.0
# 6  anderson  58.0      F    manager   180.0

# %%
df = merge_outer.copy()
df.sort_values(by = 'age', inplace = True)
df.index = range(0, df.shape[0])
df
# Out:
#        name   age gender        job  height
# 0     alice  19.0      F    student   165.0
# 1      eric  22.0      M    student   175.0
# 2      john  26.0      M    student   180.0
# 3     peter  33.0      M   engineer     NaN
# 4     julie  44.0      F  scientist   169.0
# 5      paul  58.0      F    manager     NaN
# 6  anderson   NaN    NaN        NaN   180.0

# %%
df.fillna(method = 'bfill', inplace = True)    # backward fill
df
# Out:
#        name   age gender        job  height
# 0     alice  19.0      F    student   165.0
# 1      eric  22.0      M    student   175.0
# 2      john  26.0      M    student   180.0
# 3     peter  33.0      M   engineer   169.0
# 4     julie  44.0      F  scientist   169.0
# 5      paul  58.0      F    manager   180.0
# 6  anderson   NaN    NaN        NaN   180.0

# %% [markdown]
# #### Rename Column Names

# %%
df = users.copy()
print (df.columns)
df
# Out:
# Index(['name', 'age', 'gender', 'job'], dtype='object')
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
df = df.rename(columns={'name':'emp_name', 'age':'emp_age', 'gender':'emp_gender'})
df
# Out:
#   emp_name  emp_age emp_gender        job
# 0    alice       19          F    student
# 1     john       26          M    student
# 2     eric       22          M    student
# 3     paul       58          F    manager
# 4    peter       33          M   engineer
# 5    julie       44          F  scientist

# %%
new_column_name = ['new_emp_name', 'new_emp_age', 'new_emp_gender', 'new_emp_job']
df.columns = new_column_name
df
# Out:
#   new_emp_name  new_emp_age new_emp_gender new_emp_job
# 0        alice           19              F     student
# 1         john           26              M     student
# 2         eric           22              M     student
# 3         paul           58              F     manager
# 4        peter           33              M    engineer
# 5        julie           44              F   scientist

# %% [markdown]
# #### Group By on Data Frame

# %%
df = users.copy()
df
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 2   eric   22      M    student
# 3   paul   58      F    manager
# 4  peter   33      M   engineer
# 5  julie   44      F  scientist

# %%
for group, data_frame in df.groupby('job'):
    print (type(group), type(data_frame))
    print ("group:", group)
    print (data_frame)
# Out:
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# group: engineer
#     name  age gender       job
# 4  peter   33      M  engineer
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# group: manager
#    name  age gender      job
# 3  paul   58      F  manager
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# group: scientist
#     name  age gender        job
# 5  julie   44      F  scientist
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# group: student
#     name  age gender      job
# 0  alice   19      F  student
# 1   john   26      M  student
# 2   eric   22      M  student

# %%
for group, data_frame in df.groupby('gender'):
    print (type(group), type(data_frame))
    print ("group:", group)
    print (data_frame)
# Out:
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# group: F
#     name  age gender        job
# 0  alice   19      F    student
# 3   paul   58      F    manager
# 5  julie   44      F  scientist
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# group: M
#     name  age gender       job
# 1   john   26      M   student
# 2   eric   22      M   student
# 4  peter   33      M  engineer

# %%
grouped_df = df.groupby('job').agg({'age':['sum', 'mean', 'max', 'min'], 'gender': ['count']})
grouped_df
# Out:
#           age                    gender
#           sum       mean max min  count
# job
# engineer   33  33.000000  33  33      1
# manager    58  58.000000  58  58      1
# scientist  44  44.000000  44  44      1
# student    67  22.333333  26  19      3

# %%
grouped_df = df.groupby('job').agg({'age':['sum', 'mean', 'max', 'min'], 'gender': 'count'})
grouped_df
# Out:
#           age                    gender
#           sum       mean max min  count
# job
# engineer   33  33.000000  33  33      1
# manager    58  58.000000  58  58      1
# scientist  44  44.000000  44  44      1
# student    67  22.333333  26  19      3

# %% [markdown]
# #### Reading Data to DataFrame from External Sources

# %%
try:
    print ("Read data from the .CSV data file...")
    # df = pd.read_csv("salary_table.csv")
    df = pd.read_csv("./salary_table.csv")
    # df = pd.read_csv(".//salary_table.csv")
    # df = pd.read_csv(".\salary_table.csv")
    # df = pd.read_csv(".\\salary_table.csv")
    # df = pd.read_csv("C:\\Users\Arnab\LPU\salary_table.csv")
    # df = pd.read_csv("C:\\Users\\Arnab\\LPU\\salary_table.csv")
    # df = pd.read_csv("C:/Users/Arnab/LPU/salary_table.csv")
    # df = pd.read_csv("C://Users//Arnab//LPU//salary_table.csv")
    print ("Data file has been read successfully...")
except:
    print ("File access ERROR !!!")
    print ("Data file could not be read successfully...")
df.head()
# Out:
# Read data from the .CSV data file...
# Data file has been read successfully...
#    salary  experience education management
# 0   13876           1  Bachelor          Y
# 1   11608           1      Ph.D          N
# 2   18701           1      Ph.D          Y
# 3   11283           1    Master          N
# 4   11767           1      Ph.D          N

# %% [markdown]
# Class Assignment:
# Find the average, maximum, minimum and total salary based on the group by on 'education' from the csv file.
# Find the average, maximum, minimum and total salary based on the group by on 'management' from the csv file.

# %%
group_output1 = df.groupby('education').agg({'salary':['min', 'max', 'mean', 'sum']})
group_output1
# Out:
#           salary
#              min    max          mean     sum
# education
# Bachelor   10535  19346  14941.500000  209181
# Master     11283  27837  18286.368421  347441
# Ph.D       11608  25685  18292.846154  237807

# %%
group_output2 = df.groupby('management').agg({'salary':['min', 'max', 'mean', 'sum']})
group_output2
# Out:
#            salary
#               min    max          mean     sum
# management
# N           10535  19346  14285.307692  371418
# Y           13876  27837  21150.550000  423011

# %%
try:
    print ("Reading data from the .XLSX file...")
    # df = pd.read_excel("C:\\Users\Arnab\LPU\Online Retail.xlsx")
    # df = pd.read_excel("C:\\Users\Arnab\LPU\Online Retail.xlsx", sheet_name='Sheet2')
    df = pd.read_excel("C:\\Users\Arnab\LPU\Online Retail.xlsx", sheet_name='Sheet1')
    print ("Data file has been read successfully...")
except:
    print ("File access ERROR !!!")
    print ("Data file could not be read successfully...")
df.head()
# Out:
# Reading data from the .XLSX file...
# Data file has been read successfully...
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536403     22867              HAND WARMER BIRD DESIGN        96
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4 2010-12-01 11:27:00       1.85       12791     Netherlands

# %% [markdown]
# #### Insert and Delete Columns and Replace Column Values

# %%
df1 = pd.read_excel("C:\\Users\Arnab\LPU\Online Retail.xlsx", sheet_name='Sheet2')
df1.head()
# Out:
#    INVOICENO STOCKCODE                          DESCRIPTION  QUANTITY  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536403     22867              HAND WARMER BIRD DESIGN        96
#
#           INVOICEDATE  UNITPRICE  CUSTOMERID         COUNTRY
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4 2010-12-01 11:27:00       1.85       12791     Netherlands

# %%
df1 = df1[["INVOICENO", "UNITPRICE", "CUSTOMERID", "COUNTRY"]]
df1.head()
# Out:
#    INVOICENO  UNITPRICE  CUSTOMERID         COUNTRY
# 0     536365       2.55       17850  United Kingdom
# 1     536365       3.39       17850  United Kingdom
# 2     536365       2.75       17850  United Kingdom
# 3     536365       3.39       17850  United Kingdom
# 4     536403       1.85       12791     Netherlands

# %%
df1.drop("INVOICENO", axis = 1, inplace = True)   # deleting column "INVOICENO"
df1.head()
# Out:
#    UNITPRICE  CUSTOMERID         COUNTRY
# 0       2.55       17850  United Kingdom
# 1       3.39       17850  United Kingdom
# 2       2.75       17850  United Kingdom
# 3       3.39       17850  United Kingdom
# 4       1.85       12791     Netherlands

# %%
df1.insert(1, 'TAX', df1.UNITPRICE * 0.10)    # inserting column 'TAX' at index 1
df1.head()
# Out:
#    UNITPRICE    TAX  CUSTOMERID         COUNTRY
# 0       2.55  0.255       17850  United Kingdom
# 1       3.39  0.339       17850  United Kingdom
# 2       2.75  0.275       17850  United Kingdom
# 3       3.39  0.339       17850  United Kingdom
# 4       1.85  0.185       12791     Netherlands

# %%
# replacing COUNTRY column values
df1.COUNTRY.value_counts()
# Out:
# United Kingdom    4
# Australia         4
# France            4
# Netherlands       2
# Germany           1
# Name: COUNTRY, dtype: int64

# %%
df1['COUNTRY'].replace(["France", "United Kingdom", "Australia", "Netherlands", "Germany"], ["Fr", "UK", "Aus", "Ned", "Gr"],inplace=True)
df1
# Out:
#     UNITPRICE    TAX  CUSTOMERID COUNTRY
# 0        2.55  0.255       17850      UK
# 1        3.39  0.339       17850      UK
# 2        2.75  0.275       17850      UK
# 3        3.39  0.339       17850      UK
# 4        1.85  0.185       12791     Ned
# 5       15.00  1.500       12791     Ned
# 6        8.50  0.850       12431     Aus
# 7        4.95  0.495       12431     Aus
# 8        1.25  0.125       12431     Aus
# 9        5.45  0.545       12431     Aus
# 10       3.75  0.375       12583      Fr
# 11       3.75  0.375       12583      Fr
# 12       1.25  0.125       12583      Fr
# 13       2.95  0.295       12583      Fr
# 14      18.00  1.800       12662      Gr

# %%
df1['COUNTRY'].replace({"Fr":"France", "UK":"United Kingdom", "Aus":"Australia", "Ned":"Netherlands", "Gr":"Germany"}, inplace=True)
df1
# Out:
#     UNITPRICE    TAX  CUSTOMERID         COUNTRY
# 0        2.55  0.255       17850  United Kingdom
# 1        3.39  0.339       17850  United Kingdom
# 2        2.75  0.275       17850  United Kingdom
# 3        3.39  0.339       17850  United Kingdom
# 4        1.85  0.185       12791     Netherlands
# 5       15.00  1.500       12791     Netherlands
# 6        8.50  0.850       12431       Australia
# 7        4.95  0.495       12431       Australia
# 8        1.25  0.125       12431       Australia
# 9        5.45  0.545       12431       Australia
# 10       3.75  0.375       12583          France
# 11       3.75  0.375       12583          France
# 12       1.25  0.125       12583          France
# 13       2.95  0.295       12583          France
# 14      18.00  1.800       12662         Germany

# %%
# factorizing COUNTRY column values
df1.insert(4, "COUNTRY_CODE", pd.factorize(df1['COUNTRY'])[0])
df1
# Out:
#     UNITPRICE    TAX  CUSTOMERID         COUNTRY  COUNTRY_CODE
# 0        2.55  0.255       17850  United Kingdom             0
# 1        3.39  0.339       17850  United Kingdom             0
# 2        2.75  0.275       17850  United Kingdom             0
# 3        3.39  0.339       17850  United Kingdom             0
# 4        1.85  0.185       12791     Netherlands             1
# 5       15.00  1.500       12791     Netherlands             1
# 6        8.50  0.850       12431       Australia             2
# 7        4.95  0.495       12431       Australia             2
# 8        1.25  0.125       12431       Australia             2
# 9        5.45  0.545       12431       Australia             2
# 10       3.75  0.375       12583          France             3
# 11       3.75  0.375       12583          France             3
# 12       1.25  0.125       12583          France             3
# 13       2.95  0.295       12583          France             3
# ...

# %% [markdown]
# #### Populating Data on a DataFrame in Google Colab

# %% [markdown]
# **Strategy-1:** Reading Data Files

# %%
from google.colab import files
uploaded = files.upload()

# %%
import io
import pandas as pd
df1 = pd.read_csv(io.BytesIO(uploaded['salary_table.csv']))
df1.head()

# %% [markdown]
# **Strategy-2:** Reading Data Files

# %%
from google.colab import drive
drive.mount("/content/gdrive")

# %%
import pandas as pd
# prior executing the next line, upload the data file in the Google drive
df = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/iris.csv")
df.head()

# %% [markdown]
# #### Data Visualization with DataFrame

# %%
df = pd.read_csv("salary_table.csv")
df.head()
# Out:
#    salary  experience education management
# 0   13876           1  Bachelor          Y
# 1   11608           1      Ph.D          N
# 2   18701           1      Ph.D          Y
# 3   11283           1    Master          N
# 4   11767           1      Ph.D          N

# %%
print (min(df.salary), max(df.salary), min(df.experience), max(df.experience), df.shape)
# Out:
# 10535 27837 1 20 (46, 4)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.experience.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.experience.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df["experience"].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.experience.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
df.experience.plot.line()
# Out:
# <AxesSubplot:>

# %%
df.salary.head(10)
# Out:
# 0    13876
# 1    11608
# 2    18701
# 3    11283
# 4    11767
# 5    20872
# 6    11772
# 7    10535
# 8    12195
# 9    12313
# Name: salary, dtype: int64

# %%
df.salary.head(10).plot.pie()
# Out:
# <AxesSubplot:ylabel='salary'>

# %%
df.salary.head(10).plot.pie(autopct = "%.2f")
# Out:
# <AxesSubplot:ylabel='salary'>

# %%
df.salary.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.experience.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = "scatter", x = "experience", y = "salary", s = 50, title = "Experience (In Years) vs. Salary (In INR)...")
# Out:
# <AxesSubplot:title={'center':'Experience (In Years) vs. Salary (In INR)...'}, xlabel='experience', ylabel='salary'>
